# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Sample DataFrame
data = {
    'Category': np.random.choice(['A', 'B', 'C', 'D'], 100),
    'Value': np.random.randint(1, 100, 100),
    'Score': np.random.randn(100) * 15 + 50,
    'Gender': np.random.choice(['Male', 'Female'], 100),
    'Age': np.random.randint(18, 60, 100)
}
df = pd.DataFrame(data)
df
# Out:
#    Category  Value      Score  Gender  Age
# 0         A      6  35.660664    Male   29
# 1         B     28  55.574072  Female   53
# 2         D     41  44.434018  Female   52
# 3         D     70  37.277652    Male   46
# 4         D     25  73.540196    Male   22
# ..      ...    ...        ...     ...  ...
# 95        B     39  52.599205    Male   50
# 96        C     49  61.457428  Binary   50
# 97        D     28  69.443212    Male   37
# 98        C      6  80.926945    Male   56
# 99        C     60  35.730337    Male   52
#
# [100 rows x 5 columns]

# %%
# Basic Visualizations
sns.set(style="whitegrid")

# %%
# 1. Bar Plot
plt.figure(figsize=(8, 5))
sns.barplot(x='Category', y='Value', data=df)
plt.title('Bar Plot')
plt.show()

# %%
# 2. Count Plot
plt.figure(figsize=(8, 5))
sns.countplot(x='Category', hue='Gender', data=df)
plt.title('Count Plot')
plt.show()

# %%
# 3. Box Plot
plt.figure(figsize=(8, 5))
sns.boxplot(x='Category', y='Score', data=df)
plt.title('Box Plot')
plt.show()

# %%
# 4. Violin Plot
plt.figure(figsize=(8, 5))
sns.violinplot(x='Category', y='Score', data=df)
plt.title('Violin Plot')
plt.show()

# %%
# 5. Strip Plot
plt.figure(figsize=(8, 5))
sns.stripplot(x='Category', y='Value', data=df, jitter=True)
plt.title('Strip Plot')
plt.show()

# %%
# 6. Swarm Plot
plt.figure(figsize=(8, 5))
sns.swarmplot(x='Category', y='Value', data=df)
plt.title('Swarm Plot')
plt.show()

# %%
# 7. Histogram
plt.figure(figsize=(8, 5))
sns.histplot(df['Score'], bins=20, kde=True)
plt.title('Histogram')
plt.show()

# %%
# 8. KDE Plot
plt.figure(figsize=(8, 5))
sns.kdeplot(df['Score'], shade=True)
plt.title('KDE Plot')
plt.show()
# Out:
# C:\Users\Zarin Hasan\AppData\Local\Temp\ipykernel_19868\1369962447.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Score'], shade=True)

# %%
# 9. Scatter Plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Age', y='Score', hue='Gender', data=df)
plt.title('Scatter Plot')
plt.show()

# %%
# 10. Pair Plot
sns.pairplot(df, hue='Gender')
plt.suptitle('Pair Plot', y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories_1 = ['A', 'B', 'C', 'D']
values_1 = [5, 15, 25, 35]

# Plot bar chart
plt.bar(categories_1, values_1)

# Add data labels
for index, value in enumerate(values_1):
    plt.text(index, value + 1, str(value), ha='center')

# Title and show plot
plt.title("Bar Chart with Data Labels")
plt.show()
