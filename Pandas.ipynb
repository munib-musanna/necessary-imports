# %%
import pandas as pd

# %% [markdown]
# # 1. Data Importing
#
# - pd.read_csv()
#
# - pd.read_table()
#
# - pd.read_excel()
#
# - pd.read_sql()
#
# - pd.read_json()
#
# - pd.read_html()

# %% [markdown]
# # 2. Data Cleaning
#
# - pd.fillna()
# - pd.dropna()
# - pd.sort_values()
# - pd.fillna()
# - pd.groupby()
# - pd.join()
# - pd.append()

# %% [markdown]
# # 3. Data Statistics
#
# - pd.head()
# - pd.tail()
# - pd.info()
# - pd.describe()
# - pd.mean()
# - pd.median()
# - pd.count()
# - pd.std()
# - pd.max()
# - pd.min()
# - pd.unique()

# %%
Dataset = pd.read_csv("Data_December.csv")
Dataset
# Out:
#       Date No:        Date                 Code        Customer Employee Name  \
# 0            1   12/1/2023  S-01-12-2023-274341      Abdul Alim   Zahid - 217
# 1            1   12/1/2023  S-01-12-2023-274341      Abdul Alim   Zahid - 217
# 2            1   12/1/2023  S-01-12-2023-274341      Abdul Alim   Zahid - 217
# 3            1   12/1/2023  S-01-12-2023-274340           Sakib    Arif - 007
# 4            1   12/1/2023  S-01-12-2023-274339    Major Parvej  Mehedi - 165
# ...        ...         ...                  ...             ...           ...
# 9759        31  12/31/2023  S-31-12-2023-283715           Shuvo  Tanver - 321
# 9760        31  12/31/2023  S-31-12-2023-283715           Shuvo  Tanver - 321
# 9761        31  12/31/2023  S-31-12-2023-283209  Mohammad Fahad      Nur - TS
# 9762        31  12/31/2023  S-31-12-2023-280832  Rubaiya Obayed  Ashish - 014
# 9763        31  12/31/2023  S-31-12-2023-277692          Musfiq    Arif - 007
#
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9764 entries, 0 to 9763
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date No:         9764 non-null   int64
#  1   Date             9764 non-null   object
#  2   Code             9764 non-null   object
#  3   Customer         9763 non-null   object
#  4   Employee Name    9764 non-null   object
#  5   Group            9764 non-null   object
#  6   Item Code        9764 non-null   int64
#  7   Item Group Name  9764 non-null   object
#  8   Category         9764 non-null   object
#  9   Category_N       9764 non-null   object
#  10  Brand            8753 non-null   object
#  11  Item Name        9764 non-null   object
#  12  O/UN-O           9764 non-null   object
#  13  Serial           6933 non-null   object
#  14  Qty              9764 non-null   int64
#  15  Price            9764 non-null   int64
# ...

# %%
Dataset.head()
# Out:
#    Date No:       Date                 Code      Customer Employee Name  \
# 0         1  12/1/2023  S-01-12-2023-274341    Abdul Alim   Zahid - 217
# 1         1  12/1/2023  S-01-12-2023-274341    Abdul Alim   Zahid - 217
# 2         1  12/1/2023  S-01-12-2023-274341    Abdul Alim   Zahid - 217
# 3         1  12/1/2023  S-01-12-2023-274340         Sakib    Arif - 007
# 4         1  12/1/2023  S-01-12-2023-274339  Major Parvej  Mehedi - 165
#
#     Group  Item Code     Item Group Name       Category     Category_N  Brand  \
# 0  B.City       5616  Power & Smart Tech  Power Adapter  Power Adapter  Anker
# 1  B.City        912   Apple Accessories     Data Cable     Data Cable  Apple
# 2  B.City      22672        Used Devices  iPhone - Used  iPhone - Used  Apple
# 3  B.City      19858  Power & Smart Tech  Power Adapter  Power Adapter  Anker
# 4  B.City       3037             Outfits  Macbook Cover  Macbook Cover   WiWu
#
# ...

# %%
Dataset.tail()
# Out:
#       Date No:        Date                 Code        Customer Employee Name  \
# 9759        31  12/31/2023  S-31-12-2023-283715           Shuvo  Tanver - 321
# 9760        31  12/31/2023  S-31-12-2023-283715           Shuvo  Tanver - 321
# 9761        31  12/31/2023  S-31-12-2023-283209  Mohammad Fahad      Nur - TS
# 9762        31  12/31/2023  S-31-12-2023-280832  Rubaiya Obayed  Ashish - 014
# 9763        31  12/31/2023  S-31-12-2023-277692          Musfiq    Arif - 007
#
#        Group  Item Code Item Group Name                Category  \
# 9759      TS      23338         Outfits  Phone Screen Protector
# 9760      TS       2574         Outfits         Polly / Sticker
# 9761      TS      22227     New Devices            Nokia Mobile
# 9762      TS      23354     New Devices                  iPhone
# 9763  B.City      23965    Used Devices     honor Mobile - Used
#
#                   Category_N  Brand  \
# 9759  Phone Screen Protector  Anank
# ...

# %%
Dataset.describe()
# Out:
#           Date No:     Item Code          Qty          Price          Total
# count  9764.000000   9764.000000  9764.000000    9764.000000    9764.000000
# mean     16.150348  14712.075072     1.039226   21413.645535   21669.316364
# std       9.157589   9445.562770     0.492905   41689.791203   42374.782505
# min       1.000000     19.000000     1.000000       1.000000       1.000000
# 25%       8.000000   4209.000000     1.000000    1200.000000    1200.000000
# 50%      16.000000  20530.000000     1.000000    2900.000000    3000.000000
# 75%      24.000000  22882.000000     1.000000   15800.000000   16025.000000
# max      31.000000  24148.000000    28.000000  345000.000000  345000.000000

# %%
Dataset["Price"].mean()
# Out:
# 21413.64553461696

# %%
Dataset["Price"].median()
# Out:
# 2900.0

# %%
Dataset["I_Group"].unique()
# Out:
# array(['Power Tech', 'Devices', 'N|A', 'Smart Tech', 'Sound Tech',
#        'Smart Watch'], dtype=object)

# %%
Dataset["Price"].std()
# Out:
# 41689.791203045774

# %%
Dataset["Price"].min()
# Out:
# 1

# %%
Dataset["Price"].max()
# Out:
# 345000
